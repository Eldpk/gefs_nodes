# %%
import numpy as np
import xarray as xr
from minisom import MiniSom
import pandas as pd
from sklearn.preprocessing import RobustScaler
import pprint
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.gridspec import GridSpec
import matplotlib.colors as mcolors
from matplotlib import colormaps as cm
from som_2var_training_new import read_and_transform, build_scaler, train_som
# Out:
# /home/z2034747/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 13
#      11 import matplotlib.colors as mcolors
#      12 from matplotlib import colormaps as cm
# ---> 13 from som_2var_training_new import read_and_transform, build_scaler, train_som
#
# ModuleNotFoundError: No module named 'som_2var_training_new'

# %% [markdown]
# # Old and doesn't work

# %%
prefs = {'filename': "/home/z2034747/Research/Datasets/Combined/spring_z500_td2m.nc", 
         'vars': ['z500', 'td2m'], 'wlon': 220, 'elon': 305, 'nlat': 55, 'slat': 20, 
         'som_config': {'x': 4, 'y': 4, 'sigma': 0.5, 'random_seed': 42},
         'som_train': {'num_iteration': 10000, 'random_order': True, 'verbose': True}}

trained_som, trained_scaler, train_info, xr_data = train_som(prefs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 6
#       1 prefs = {'filename': "/home/z2034747/Research/Datasets/Combined/spring_z500_td2m.nc",
#       2          'vars': ['z500', 'td2m'], 'wlon': 220, 'elon': 305, 'nlat': 55, 'slat': 20,
#       3          'som_config': {'x': 4, 'y': 4, 'sigma': 0.5, 'random_seed': 42},
#       4          'som_train': {'num_iteration': 10000, 'random_order': True, 'verbose': True}}
# ----> 6 trained_som, trained_scaler, train_info, xr_data = train_som(prefs)
#
# File ~/Research/Notebooks/som_2var_training_new.py:98, in train_som(preferences)
#      75 def train_som(preferences):
#      76     """Trains the SOM by reading in the data based on
#      77     the preferences and performs preprocessing tasks
#      78     and provides training output messages.
#    (...)
# ...

# %%
print(prefs['vars'])
# Out:
# ['z500', 'pwat']

# %%
ds = xr.open_dataset(prefs['filename'])
ds_sel = ds[prefs['vars']]

# %%
ds_sel
# Out:
# <xarray.Dataset> Size: 26MB
# Dimensions:  (time: 263, lat: 71, lon: 171)
# Coordinates:
#   * time     (time) datetime64[ns] 2kB 2000-03-01 2000-03-08 ... 2019-05-29
#   * lat      (lat) float32 284B 55.0 54.5 54.0 53.5 53.0 ... 21.5 21.0 20.5 20.0
#   * lon      (lon) float32 684B 220.0 220.5 221.0 221.5 ... 304.0 304.5 305.0
# Data variables:
#     z500     (time, lat, lon) float32 13MB ...
#     td2m     (time, lat, lon) float32 13MB ...

# %%
arrays = np.array([])

# %%
arrays = []
for var in ds.data_vars:
    flat = ds[var].values.ravel()
    arrays.append(flat)
final_array = np.concatenate([
    array for array in arrays
])

# %%
final_array
# Out:
# array([5257.9146  , 5265.358   , 5272.5454  , ...,   20.931818,
#          21.022728,   21.0625  ], dtype=float32)

# %%
final_array.shape
# Out:
# (6386166,)

# %%
type(final_array)
# Out:
# numpy.ndarray

# %%
prefs = {'filename': "/home/z2034747/Research/Datasets/Combined/spring_z500_td2m.nc", 
         'vars': ['z500', 'td2m'], 'wlon': 220, 'elon': 305, 'nlat': 55, 'slat': 20, 
         'som_config': {'x': 4, 'y': 4, 'sigma': 0.5, 'random_seed': 42},
         'som_train': {'num_iteration': 10000, 'random_order': True, 'verbose': True}}

trained_som, trained_scaler, train_info, xr_data = train_som(prefs)
